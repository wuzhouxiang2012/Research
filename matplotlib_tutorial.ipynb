# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Functional Plot

# %%
x1 = np.linspace(0,5,num=10)
y1 = x1**2
plt.plot(x1,y1)
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
# Out:
# Text(0, 0.5, 'Days Squared')

# %% [markdown]
# ## Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x1,y1, 'r')
plt.subplot(1,2,2)
plt.plot(x1,y1,'b')

# %% [markdown]
# ## Using Figure Objects

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.set_xlabel('Days')
axes_1.set_ylabel('Days Squred')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x1, y1, label='x/x^2')
axes_1.plot(y1,x1, label='x^2/x')
axes_1.legend(loc=0)
# upper right 1, upper left 2, lower left 3, lower right 4
# supply a tuple of x and y from lower left

axes_2 = fig_1.add_axes([0.45,0.45, 0.4,0.3])
axes_2.set_xlabel('Days')
axes_2.set_ylabel('Days Squred')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x1, y1, label='x/x^2')
axes_2.plot(y1,x1, label='x^2/x')
axes_2.legend(loc=0)
axes_2.text(0,40, 'Message') # center is 0,0
# Out:
# Text(0, 40, 'Message')

# %%
fig_1.savefig('squre.png')

# %% [markdown]
# ## SubPlots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout()
axes_2[1].set_title('Plot 2')
axes_2[1].set_xlabel('Days')
axes_2[1].set_ylabel('Square of Days')
axes_2[1].plot(x1,y1)

# %% [markdown]
# # Tex

# %%
fig_3 = plt.figure(figsize=(8,4))
axes_3 = fig_3.add_axes([0.1,0.1,0.9,0.9])
axes_3.plot(x,y)
axes_3.set_xlabel(r'$x$')
axes_3.set_ylabel(r'$x^2$')
axes_3.text(0,20, r'$\alpha \beta \sum_{i=1}^{n^2}$')
# Out:
# Text(0, 20, '$\\alpha \\beta \\sum_{i=1}^{n^2}$')

# %%
arr1 = np.random.randint(0,7, 5000)
arr2 = np.random.randint(0,7,5000)
arr3 = arr1+arr2
plt.subplot(131)
plt.hist(x=arr3, bins=11, density=False)
plt.subplot(132)
plt.hist(x=arr3, bins=11, density=False, histtype='step')
plt.subplot(133)
plt.hist(x=arr3, bins=11, density=False, orientation='horizontal')
"""
x, bins=None, range=None, density=False, weights=None,
        cumulative=False, bottom=None, histtype='bar', align='mid',
        orientation='vertical', rwidth=None, log=False, color=None,
        label=None, stacked=False, *, data=None, **kwargs
range gets tuple with bin range interested in
cumulative: use cumulative distribution
histtype='step'
"""
# Out:
# "\nx, bins=None, range=None, density=False, weights=None,\n        cumulative=False, bottom=None, histtype='bar', align='mid',\n        orientation='vertical', rwidth=None, log=False, color=None,\n        label=None, stacked=False, *, data=None, **kwargs\nrange gets tuple with bin range interested in\ncumulative: use cumulative distribution\nhisttype='step'\n"

# %%
x=['Nuclear', 'Hydro', 'Coal', 'Gas', 'Solar', 'Wind', 'Other']
per_1 = [71,10,3,7,2,4,3]
variance = [8,3,1,3,1,2,1]
plt.bar(x, per_1, color='purple', yerr=variance)
# Out:
# <BarContainer object of 7 artists>

# %%
m_eng =(76,85,86,88,93)
f_eng =(24,15,14,12,7)
spc = np.arange(5)
plt.bar(spc, m_eng, width=0.45, label='Male', edgecolor='k')
plt.bar(spc+0.45, f_eng, width=0.45, label='Female', edgecolor='k')
plt.xticks(spc+0.45/2, ('Aero', 'Chem', 'Civil', 'Elec', 'Mech'))
# Out:
# ([<matplotlib.axis.XTick at 0x7f22528ff610>,
#   <matplotlib.axis.XTick at 0x7f22528ff7f0>,
#   <matplotlib.axis.XTick at 0x7f22525b2790>,
#   <matplotlib.axis.XTick at 0x7f2252868970>,
#   <matplotlib.axis.XTick at 0x7f22528682e0>],
#  [Text(0.225, 0, 'Aero'),
#   Text(1.225, 0, 'Chem'),
#   Text(2.225, 0, 'Civil'),
#   Text(3.225, 0, 'Elec'),
#   Text(4.225, 0, 'Mech')])

# %%
t_type=['Kind', 'Elem', 'Sec', 'Spec']
m_teach = np.array([2,20,44,14])
f_teach = np.array([98,80,56,86])
ind = list(range(len(t_type)))
plt.bar(ind, m_teach, width=0.45, label='Male', bottom=f_teach)
plt.bar(ind, f_teach, width=0.45, label='Female')
plt.legend(loc=0)
